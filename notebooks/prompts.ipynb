# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hydra import compose, initialize

from falldet.data.video_dataset import label2idx
from falldet.inference.prompts import PromptBuilder, PromptConfig

# %%
with initialize(version_base=None, config_path="../config/"):
    cfg = compose(overrides=["+experiment=debug", "+prompt=baseline", "+model=qwenvl"])
    print(cfg)

# %%
# Build prompt from config
prompt_config = PromptConfig(
    output_format="text",
    role_variant="video_specialized",
    task_variant="extended",
    labels_variant="comma",
    definitions_variant="extended",
    cot=False,
    labels=list(label2idx.keys()),
    model_family="qwen",
)
prompt_builder = PromptBuilder(prompt_config, label2idx)
prompt = prompt_builder.build_prompt()
parser = prompt_builder.get_parser()
system_message = prompt_builder.get_system_message()

# %%
print(prompt)
